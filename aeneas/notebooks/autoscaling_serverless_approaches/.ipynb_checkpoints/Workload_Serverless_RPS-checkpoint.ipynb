# %% [markdown]
# # Deploying functions

# %%
#Reference
#https://docs.openfaas.com/tutorials/kubernetes-hpa/

# %%
#Deploy function and enable the function auto scaling by openfaas
# !ssh ubuntu@172.17.141.197 "cd scalingsdp;faas deploy  -f aeneas.yml --annotation topic="aeneas" --env max_inflight=50 --label com.openfaas.scale.min=1 --label com.openfaas.scale.max=15 --label com.openfaas.scale.target=5 --label com.openfaas.scale.type=rps --label com.openfaas.scale.target-proportion=0.90;"
# Out:
# Deploying: aeneas.
#
# Deployed. 202 Accepted.
# URL: http://127.0.0.1:8080/function/aeneas

# %%
#Deploy function and enable the function auto scaling by openfaas
# !ssh ubuntu@172.17.141.197 "cd scalingsdp;faas deploy  -f scaling-aeneas-tocloud.yml --annotation topic="tocloud" --label com.openfaas.scale.min=1 --label com.openfaas.scale.max=1 --label com.openfaas.scale.target=50 --label com.openfaas.scale.type=rps --label com.openfaas.scale.target-proportion=0.90;"
# Out:
# Deploying: scaling-aeneas-tocloud.
#
# Deployed. 202 Accepted.
# URL: http://127.0.0.1:8080/function/scaling-aeneas-tocloud

# %%
# !ssh ubuntu@172.17.141.197 "cd scalingsdp;faas deploy  -f getobject.yml  --label com.openfaas.scale.min=1 --label com.openfaas.scale.max=1 --label com.openfaas.scale.target=50 --label com.openfaas.scale.type=rps --label com.openfaas.scale.target-proportion=0.90;"
# Out:
# Deploying: getobject.
#
# Deployed. 202 Accepted.
# URL: http://127.0.0.1:8080/function/getobject

# %%
# !ssh ubuntu@172.17.141.197 "cd scalingsdp;faas deploy  -f pubrabbitmq.yml  --label com.openfaas.scale.min=1 --label com.openfaas.scale.max=1 --label com.openfaas.scale.target=50 --label com.openfaas.scale.type=rps --label com.openfaas.scale.target-proportion=0.90;"
# Out:
# Deploying: pubrabbitmq.
#
# Deployed. 202 Accepted.
# URL: http://127.0.0.1:8080/function/pubrabbitmq

# %%
# !ssh ubuntu@172.17.141.197 "faas describe scaling-aeneas-mqtt"
# Out:
# Name:               scaling-aeneas-mqtt
# Status:             Ready
# Replicas:           1
# Available Replicas: 1
# Invocations:        1736
# Image:              shivupoojar/scaling-aeneas-mqtt:v3
# Function Process:   sh ./index.sh
# URL:                http://127.0.0.1:8080/function/scaling-aeneas-mqtt
# Async URL:          http://127.0.0.1:8080/async-function/scaling-aeneas-mqtt
# Labels:
#  com.openfaas.scale.min: 1
#  com.openfaas.scale.target: 5
#  com.openfaas.scale.target-proportion: 0.90
#  com.openfaas.scale.type: rps
#  faas_function: scaling-aeneas-mqtt
#  uid: 644770939
#  com.openfaas.scale.max: 15
# Annotations:
#  prometheus.io.scrape: false
#  topic: aeneas
# Limits:  CPU: 1
#  Memory: 512Mi

# %% [markdown]
# # Deploying Rabbitmq Connector

# %%
# Deploying connector configurartion
# !ssh ubuntu@172.17.141.197 "cd rabbitmq-connector/artifacts;sudo kubectl apply -f cf.yaml"
# Out:
# configmap/rabbitmq-connector-configmap unchanged

# %%
# Deploy connector
# !ssh ubuntu@172.17.141.197 "cd rabbitmq-connector/artifacts;sudo kubectl apply  -f configmap.yaml"
# Out:
# deployment.apps/rabbitmq-connector created

# %%
# !ssh ubuntu@172.17.141.197 "sudo kubectl get po -n openfaas"
# Out:
# NAME                                 READY   STATUS    RESTARTS        AGE
# nats-5b77986b8-48p2x                 1/1     Running   4 (2d23h ago)   39d
# queue-worker-7d8668444f-tmq7b        1/1     Running   5 (2d23h ago)   24d
# alertmanager-6cd7bd5c64-hrcrt        1/1     Running   4 (2d23h ago)   24d
# basic-auth-plugin-78b958969c-tnpck   1/1     Running   4 (2d23h ago)   24d
# gateway-bf4f5d6f7-4q7kn              2/2     Running   10 (42h ago)    24d
# prometheus-7678c644d6-kkzz5          1/1     Running   3 (41h ago)     6d18h

# %% [markdown]
# # Deploying KEDA and components

# %%
#Install KEDA 
# !ssh ubuntu@172.17.141.197 "sudo kubectl apply -f https://github.com/kedacore/keda/releases/download/v2.9.0/keda-2.9.0.yaml"
# Out:
# namespace/keda unchanged
# customresourcedefinition.apiextensions.k8s.io/clustertriggerauthentications.keda.sh unchanged
# customresourcedefinition.apiextensions.k8s.io/scaledjobs.keda.sh unchanged
# customresourcedefinition.apiextensions.k8s.io/scaledobjects.keda.sh unchanged
# customresourcedefinition.apiextensions.k8s.io/triggerauthentications.keda.sh unchanged
# serviceaccount/keda-operator unchanged
# clusterrole.rbac.authorization.k8s.io/keda-external-metrics-reader unchanged
# clusterrole.rbac.authorization.k8s.io/keda-operator configured
# rolebinding.rbac.authorization.k8s.io/keda-auth-reader unchanged
# clusterrolebinding.rbac.authorization.k8s.io/keda-hpa-controller-external-metrics unchanged
# clusterrolebinding.rbac.authorization.k8s.io/keda-operator unchanged
# clusterrolebinding.rbac.authorization.k8s.io/keda-system-auth-delegator unchanged
# service/keda-metrics-apiserver unchanged
# service/keda-operator unchanged
# deployment.apps/keda-metrics-apiserver configured
# deployment.apps/keda-operator configured
# apiservice.apiregistration.k8s.io/v1beta1.external.metrics.k8s.io unchanged

# %%
#check for the keda components
# !ssh ubuntu@172.17.141.197 "sudo kubectl get po -n keda"
# Out:
# NAME                                      READY   STATUS    RESTARTS         AGE
# keda-metrics-apiserver-5b4c56c8c8-k7f2s   1/1     Running   4 (2d22h ago)    23d
# keda-operator-598b95d667-xvd8b            1/1     Running   2191 (41h ago)   23d

# %%
#Create Scaler
# !ssh ubuntu@172.17.141.197 "cd /home/ubuntu/rabbitmq-testing/sample-go-rabbitmq/deploy;sudo kubectl apply -f deploy-consumer.yaml"
# Out:
# secret/rabbitmq-consumer-secret created
# scaledobject.keda.sh/rabbitmq-connector created
# triggerauthentication.keda.sh/rabbitmq-consumer-trigger created

# %%
#Check for the created HPA
# !ssh ubuntu@172.17.141.197 "sudo kubectl describe hpa/keda-hpa-rabbitmq-connector -n openfaas"
# Out:
# Warning: autoscaling/v2beta2 HorizontalPodAutoscaler is deprecated in v1.23+, unavailable in v1.26+; use autoscaling/v2 HorizontalPodAutoscaler
# Name:                                                        keda-hpa-rabbitmq-connector
# Namespace:                                                   openfaas
# Labels:                                                      app.kubernetes.io/managed-by=keda-operator
#                                                              app.kubernetes.io/name=keda-hpa-rabbitmq-connector
#                                                              app.kubernetes.io/part-of=rabbitmq-connector
#                                                              app.kubernetes.io/version=2.9.0
#                                                              scaledobject.keda.sh/name=rabbitmq-connector
# Annotations:                                                 <none>
# CreationTimestamp:                                           Sat, 14 Jan 2023 12:43:42 +0000
# Reference:                                                   Deployment/rabbitmq-connector
# Metrics:                                                     ( current / target )
#   "s0-rabbitmq-OpenFaaS_Dex_aeneas" (target average value):  <unknown> / 20
#   "s1-rabbitmq-OpenFaaS_Dex_aeneas" (target average value):  <unknown> / 20
# Min replicas:                                                1
# Max replicas:                                                10
# Deployment pods:                                             0 current / 0 desired
# Conditions:
#   Type           Status  Reason             Message
#   ----           ------  ------             -------
#   AbleToScale    True    SucceededGetScale  the HPA controller was able to get the target's current scale
#   ScalingActive  False   ScalingDisabled    scaling is disabled since the replica count of the target is zero
# Events:          <none>

# %%
#Check for the HPA settings
# !ssh ubuntu@172.17.141.197 "sudo kubectl describe hpa/keda-hpa-rabbitmq-connector -n openfaas"
# Out:
# Warning: autoscaling/v2beta2 HorizontalPodAutoscaler is deprecated in v1.23+, unavailable in v1.26+; use autoscaling/v2 HorizontalPodAutoscaler
# Name:                                                        keda-hpa-rabbitmq-connector
# Namespace:                                                   openfaas
# Labels:                                                      app.kubernetes.io/managed-by=keda-operator
#                                                              app.kubernetes.io/name=keda-hpa-rabbitmq-connector
#                                                              app.kubernetes.io/part-of=rabbitmq-connector
#                                                              app.kubernetes.io/version=2.9.0
#                                                              scaledobject.keda.sh/name=rabbitmq-connector
# Annotations:                                                 <none>
# CreationTimestamp:                                           Sat, 14 Jan 2023 13:42:02 +0000
# Reference:                                                   Deployment/rabbitmq-connector
# Metrics:                                                     ( current / target )
#   "s0-rabbitmq-OpenFaaS_Dex_aeneas" (target average value):  <unknown> / 10
#   "s1-rabbitmq-OpenFaaS_Dex_aeneas" (target average value):  <unknown> / 500m
# Min replicas:                                                1
# Max replicas:                                                10
# Deployment pods:                                             0 current / 0 desired
# Conditions:
#   Type            Status  Reason              Message
#   ----            ------  ------              -------
#   AbleToScale     True    SucceededGetScale   the HPA controller was able to get the target's current scale
#   ScalingActive   False   ScalingDisabled     scaling is disabled since the replica count of the target is zero
#   ScalingLimited  False   DesiredWithinRange  the desired count is within the acceptable range
# Events:
#   Type     Reason                        Age                   From                       Message
#   ----     ------                        ----                  ----                       -------
#   Normal   SuccessfulRescale             12m (x2 over 29m)     horizontal-pod-autoscaler  New size: 2; reason: external metric s0-rabbitmq-OpenFaaS_Dex_aeneas(&LabelSelector{MatchLabels:map[string]string{scaledobject.keda.sh/name: rabbitmq-connector,},MatchExpressions:[]LabelSelectorRequirement{},}) above target
#   Normal   SuccessfulRescale             12m                   horizontal-pod-autoscaler  New size: 3; reason: external metric s0-rabbitmq-OpenFaaS_Dex_aeneas(&LabelSelector{MatchLabels:map[string]string{scaledobject.keda.sh/name: rabbitmq-connector,},MatchExpressions:[]LabelSelectorRequirement{},}) above target
#   Normal   SuccessfulRescale             11m                   horizontal-pod-autoscaler  New size: 4; reason: external metric s0-rabbitmq-OpenFaaS_Dex_aeneas(&LabelSelector{MatchLabels:map[string]string{scaledobject.keda.sh/name: rabbitmq-connector,},MatchExpressions:[]LabelSelectorRequirement{},}) above target
#   Warning  FailedGetExternalMetric       8m34s (x7 over 10m)   horizontal-pod-autoscaler  unable to get external metric openfaas/s1-rabbitmq-OpenFaaS_Dex_aeneas/&LabelSelector{MatchLabels:map[string]string{scaledobject.keda.sh/name: rabbitmq-connector,},MatchExpressions:[]LabelSelectorRequirement{},}: unable to fetch metrics from external metrics API: rpc error: code = Unknown desc = error when getting metric values no matching metrics found for s1-rabbitmq-openfaas_dex_aeneas
#   Warning  FailedComputeMetricsReplicas  8m34s (x7 over 10m)   horizontal-pod-autoscaler  invalid metrics (2 invalid out of 2), first error is: failed to get s0-rabbitmq-OpenFaaS_Dex_aeneas external metric: unable to get external metric openfaas/s0-rabbitmq-OpenFaaS_Dex_aeneas/&LabelSelector{MatchLabels:map[string]string{scaledobject.keda.sh/name: rabbitmq-connector,},MatchExpressions:[]LabelSelectorRequirement{},}: unable to fetch metrics from external metrics API: rpc error: code = Unknown desc = error when getting metric values no matching metrics found for s0-rabbitmq-openfaas_dex_aeneas
#   Warning  FailedGetExternalMetric       2m15s (x32 over 10m)  horizontal-pod-autoscaler  unable to get external metric openfaas/s0-rabbitmq-OpenFaaS_Dex_aeneas/&LabelSelector{MatchLabels:map[string]string{scaledobject.keda.sh/name: rabbitmq-connector,},MatchExpressions:[]LabelSelectorRequirement{},}: unable to fetch metrics from external metrics API: rpc error: code = Unknown desc = error when getting metric values no matching metrics found for s0-rabbitmq-openfaas_dex_aeneas

# %%
# Watch for every 5 seconds
# !ssh ubuntu@172.17.141.197 "watch -n 5 "kubectl describe hpa/nodeinfo -n openfaas-fn""
# Out:
# ^C

# %% [markdown]
# # Experiments

# %%
import sys
import  datetime
import os
from minio import Minio
import csv
import json
import pandas as pd
import time
import subprocess
from subprocess import Popen, PIPE
import requests
from IPython.display import display

# %%
scenario = "keda_rps_message_0.5_spawnrate_0.05"
user=10
iteration=0.05
minio_host="172.17.141.197:9001"
bucket_name="aeneas-output"
PROMETHEUS = 'http://172.17.141.197:31022/'
time_locust=30

# %%
# !rm input_data.csv
# !touch input_data.csv
# !echo "intime" > input_data.csv

# %%
# !locust --headless -f rabbitmq_locust.py --host='127.0.0.1' -t 100s  --users 10 --spawn-rate 0.05
# Out:
# [2023-01-14 19:17:46,075] ubuntu/INFO/locust.main: Run time limit set to 100 seconds
# [2023-01-14 19:17:46,075] ubuntu/INFO/locust.main: Starting Locust 2.14.0
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2023-01-14 19:17:46,079] ubuntu/INFO/locust.runners: Ramping to 10 users at a rate of 0.05 per second
# [2023-01-14 19:17:46,098] ubuntu/INFO/pika.adapters.utils.connection_workflow: Pika version 1.3.1 connecting to ('172.17.141.197', 5672)
# [2023-01-14 19:17:46,100] ubuntu/INFO/pika.adapters.utils.io_services_utils: Socket connected: <gevent._socket3.socket at 0xffff963f2be0 object, fd=3, family=2, type=1, proto=6>
# [2023-01-14 19:17:46,101] ubuntu/INFO/pika.adapters.utils.connection_workflow: Streaming transport linked up: (<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0xffff9640cd60>, _StreamingProtocolShim: <SelectConnection PROTOCOL transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0xffff9640cd60> params=<URLParameters host=172.17.141.197 port=5672 virtual_host=/ ssl=False>>).
# [2023-01-14 19:17:46,113] ubuntu/INFO/pika.adapters.utils.connection_workflow: AMQPConnector - reporting success: <SelectConnection OPEN transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0xffff9640cd60> params=<URLParameters host=172.17.141.197 port=5672 virtual_host=/ ssl=False>>
# [2023-01-14 19:17:46,114] ubuntu/INFO/pika.adapters.utils.connection_workflow: AMQPConnectionWorkflow - reporting success: <SelectConnection OPEN transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0xffff9640cd60> params=<URLParameters host=172.17.141.197 port=5672 virtual_host=/ ssl=False>>
# [2023-01-14 19:17:46,115] ubuntu/INFO/pika.adapters.blocking_connection: Connection workflow succeeded: <SelectConnection OPEN transport=<pika.adapters.utils.io_services_utils._AsyncPlaintextTransport object at 0xffff9640cd60> params=<URLParameters host=172.17.141.197 port=5672 virtual_host=/ ssl=False>>
# [2023-01-14 19:17:46,116] ubuntu/INFO/pika.adapters.blocking_connection: Created channel=1
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# BASIC_PUBLISH  test.message       1     0(0.00%) |      7       7       7      7 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       1     0(0.00%) |      7       7       7      7 |    0.00        0.00
#
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# BASIC_PUBLISH  test.message       2     0(0.00%) |      6       5       7      6 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       2     0(0.00%) |      6       5       7      6 |    0.00        0.00
#
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# BASIC_PUBLISH  test.message       2     0(0.00%) |      6       5       7      6 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       2     0(0.00%) |      6       5       7      6 |    0.00        0.00
#
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# BASIC_PUBLISH  test.message       2     0(0.00%) |      6       5       7      6 |    0.00        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       2     0(0.00%) |      6       5       7      6 |    0.00        0.00
#
# KeyboardInterrupt
# 2023-01-14T19:17:55Z
# [2023-01-14 19:17:55,165] ubuntu/INFO/locust.main: Shutting down (exit code 0)
# Type     Name  # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
# BASIC_PUBLISH  test.message       2     0(0.00%) |      6       5       7      6 |    0.76        0.00
# --------||-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated       2     0(0.00%) |      6       5       7      6 |    0.76        0.00
#
# Response time percentiles (approximated)
# Type     Name      50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------||--------|------|------|------|------|------|------|------|------|------|------|------
# BASIC_PUBLISH test.message        7      7      7      7      7      7      7      7      7      7      7      2
# --------||--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated        7      7      7      7      7      7      7      7      7      7      7      2

# %%
time.sleep(100)

# %%
df= pd.read_csv('input_data.csv')
print(df)
# Out:
#                          intime
# 0  '2023-01-14 19:17:46.122026'
# 1  '2023-01-14 19:17:48.707789'

# %%
#Minio Client
client = Minio(minio_host, access_key = "minio", secret_key ="minio123",secure=False)
# List objects from the bicket and notedown time  stamp  when they stored
objects = client.list_objects(bucket_name,recursive=True)
outtime = []
for obj in objects:
    outtime.append(obj.last_modified)#
    client.remove_object(bucket_name, obj.object_name)

# %%
df['outtime']= outtime
df['outtime']= pd.to_datetime(df['outtime'],errors='coerce').dt.tz_convert(None)
df['intime']= pd.to_datetime(df['intime'],errors='coerce')
        return (process.communicate()[0].decode("utf-8"))

# %%
#cmd1 = "sudo kubectl logs gateway-7b8d9dbb5b-rhnwl  -n openfaas -c gateway | grep getobject | cut -c 71-77 | tail -"
cmd1="ssh ubuntu@172.17.141.197 "+"sudo kubectl logs gateway-bf4f5d6f7-4q7kn  -n openfaas -c gateway  | grep /function/aeneas | grep 200 | cut -c 80-83 | tail -"+str(len(outtime))
cmd2="ssh ubuntu@172.17.141.197 "+"sudo kubectl logs gateway-bf4f5d6f7-4q7kn -n openfaas -c gateway  | grep /function/scaling-aeneas-tocloud | cut -c 96-101 | tail -"+str(len(outtime))
cmd3="ssh ubuntu@172.17.141.197 "+"sudo kubectl logs gateway-bf4f5d6f7-4q7kn -n openfaas -c gateway  | grep /function/getobject | grep POST | cut -c 71-76  | tail -"+str(len(outtime))
cmd4="ssh ubuntu@172.17.141.197 "+"sudo kubectl logs gateway-bf4f5d6f7-4q7kn -n openfaas -c gateway  | grep /function/pubrabbitmq | grep POST | cut -c 73-78 | tail -"+str(len(outtime))
df['aeneas']=(get_function_execution_time(cmd1)).split("\n")[:-1]
#df['aeneas']=(pd.to_timedelta(df['aeneas'].astype(float), unit='s'))

df['tocloud']=(get_function_execution_time(cmd2)).split("\n")[:-1]
#df['tocloud']=(pd.to_timedelta(df['tocloud'].astype(float), unit='s'))

#df['getobject']=(get_function_execution_time(cmd3)).split("\n")[:-1]
df['pubrabbitmq']=((get_function_execution_time(cmd4)).split("\n")[:-1])
#df['pubrabbitmq']=(pd.to_timedelta(df['pubrabbitmq'].astype(float), unit='s'))

df
# Out:
#                        intime                 outtime aeneas tocloud  \
# 0  2023-01-14 19:05:27.864549 2023-01-14 19:05:39.666   6.90  0.0591
# 1  2023-01-14 19:05:32.417911 2023-01-14 19:05:39.943   7.18  0.0656
# 2  2023-01-14 19:05:36.200659 2023-01-14 19:05:46.196   9.97  0.0416
# 3  2023-01-14 19:05:38.686432 2023-01-14 19:05:46.386   7.63  0.0380
# 4  2023-01-14 19:05:44.828276 2023-01-14 19:05:52.971   7.09  0.0391
# 5  2023-01-14 19:05:45.855090 2023-01-14 19:05:53.148   8.24  0.0466
# 6  2023-01-14 19:05:52.824968 2023-01-14 19:05:58.299   5.39  0.0348
# 7  2023-01-14 19:05:53.943790 2023-01-14 19:06:00.678   6.67  0.0480
# 8  2023-01-14 19:06:00.189666 2023-01-14 19:06:06.051   5.77  0.0563
# 9  2023-01-14 19:06:02.084282 2023-01-14 19:06:09.492   7.33  0.0672
# 10 2023-01-14 19:06:04.634261 2023-01-14 19:06:13.808   9.11  0.0572
# 11 2023-01-14 19:06:06.887276 2023-01-14 19:06:19.246   9.87  0.0534
# 12 2023-01-14 19:06:09.299954 2023-01-14 19:06:19.262   12.3  0.0486
# 13 2023-01-14 19:06:10.601748 2023-01-14 19:06:22.268   11.6  0.0578
# 14 2023-01-14 19:06:13.391725 2023-01-14 19:06:27.539   14.0  0.0449
# 15 2023-01-14 19:06:15.722396 2023-01-14 19:06:34.544   18.7  0.0488
# 16 2023-01-14 19:06:17.825094 2023-01-14 19:06:35.070   17.1  0.0655
# 28      0.0516  34.521401  35.0  34.5268  10_0.05_keda_rps_message_0.5
# 30      0.0535  30.499759  30.0  30.4038  10_0.05_keda_rps_message_0.5
# 29      0.0500  33.504992  34.0  33.4321  10_0.05_keda_rps_message_0.5
# 31      0.0600  39.773974  40.0  39.7503  10_0.05_keda_rps_message_0.5
# 32      0.0327  39.376547  39.0  39.4386  10_0.05_keda_rps_message_0.5
# 33      0.0352  39.439309  39.0  39.3460  10_0.05_keda_rps_message_0.5
# 34      0.0385  33.912495  34.0  33.8855  10_0.05_keda_rps_message_0.5
# 35      0.0280  44.854342  45.0  44.8372  10_0.05_keda_rps_message_0.5
# 36      0.0384  44.397881  44.0  38.4407  10_0.05_keda_rps_message_0.5
# 37      0.0559  43.915681  44.0  43.9551  10_0.05_keda_rps_message_0.5
# 38      0.0306  38.679302  39.0  44.5682  10_0.05_keda_rps_message_0.5
# 39      0.0342  43.415464  43.0  43.4466  10_0.05_keda_rps_message_0.5
# 40      0.0328  43.436622  43.0  43.3376  10_0.05_keda_rps_message_0.5

# %%
pre_url = PROMETHEUS + '/api/v1/query?query='
timestamp= pd.to_datetime(df['outtime'].iloc[-1], format='%Y-%m-%d %H:%M:%S')
time_interval = (time.mktime(timestamp.timetuple()))
#interval= int(df['TPT'].sum()) if int(df['TPT'].sum()) > 60  else 60
user=df.shape[0]

# %%
interval = (df.loc[user-1, 'outtime'] - df.loc[0, 'intime']).total_seconds()
interval= round(interval)

# %%
interval= round((df.loc[user-1, 'outtime'] - df.loc[0, 'intime']).total_seconds()) if round((df.loc[user-1, 'outtime'] - df.loc[0, 'intime']).total_seconds()) > 60  else 60
print(interval)
# Out:
# 141

# %%
def getdataprometheus(url):
    headers= {"Accept": "application/json"}
    res = json.loads(requests.post(url=url, headers=headers).content.decode('utf8', 'ignore'))
    data=res.get('data').get('result')[0].get('value')[1]
    return data

# %%
user=df.shape[0]
metrics = {'workload_type':""+str(user)+"_"+str(time_locust)+"_"+scenario,'workload_size':user,'Workload TPT':(df.loc[user-1, 'outtime'] - df.loc[0, 'intime']).total_seconds(),'Average Workload TPT':df['TPT'].mean(),'Average FET':df['FET'].mean()}

# %%
#expr_namespace_cpu_requested = 'sum(node_namespace_pod_container:container_cpu_usage_seconds_total:sum_irate{namespace="openfaas-fn"})&time='+str(time_interval)
expr_namespace_cpu_used='sum(rate(container_cpu_usage_seconds_total{container_name!="POD",namespace="openfaas-fn"}['+str(interval)+'s]))&time='+str(time_interval)
metrics['CPU_used']=getdataprometheus(pre_url+expr_namespace_cpu_used)
expr_namespace_cpu_requested='sum(kube_pod_container_resource_requests{job="kube-state-metrics", namespace="openfaas-fn", resource="cpu"})&time='+str(time_interval)
metrics['CPU_requested']=getdataprometheus(pre_url+expr_namespace_cpu_requested)

expr_pod_cpu_rabbitmq_connector = 'sum(rate(container_cpu_usage_seconds_total{container_name!="POD",namespace="openfaas",pod=~"rabbitmq.*"}['+str(interval)+'s]))&time='+str(time_interval)
expr_pod_memory_rabbitmq_connector = 'sum(rate(container_memory_usage_bytes{container_name!="POD",namespace="openfaas",pod=~"rabbitmq.*"}['+str(interval)+'s]))&time='+str(time_interval)
metrics['CPU_rabbitmq_broker_used']=getdataprometheus(pre_url+expr_pod_cpu_rabbitmq_connector)
metrics['Memory_rabbitmq_broker_used']=getdataprometheus(pre_url+expr_pod_memory_rabbitmq_connector)

expr_pod_cpu_rabbitmq_connector_requested = 'sum(kube_pod_container_resource_requests{job="kube-state-metrics", namespace="openfaas", resource="cpu",pod=~"rabbitmq.*"})&time='+str(time_interval)
expr_pod_memory_rabbitmq_connector = 'sum(rate(container_memory_usage_bytes{container_name!="POD",namespace="openfaas",pod=~"rabbitmq.*"}['+str(interval)+'s]))&time='+str(time_interval)
metrics['CPU_rabbitmq_broker_requested']=getdataprometheus(pre_url+expr_pod_cpu_rabbitmq_connector_requested)

expr_pod_rabbitmq_function = 'sum(kube_pod_container_status_ready{namespace="openfaas",pod=~"rabbitmq.*"})&time='+str(time_interval)
metrics['pod_count_rabbitmq']=getdataprometheus(pre_url+expr_pod_rabbitmq_function)

expr_pod_aeneas_function = 'sum(kube_pod_container_status_ready{namespace="openfaas-fn",pod=~"aeneas.*"})&time='+str(time_interval)
expr_pod_tocloud_function = 'sum(kube_pod_container_status_ready{namespace="openfaas-fn",pod=~"scaling-aeneas-tocloud.*"})&time='+str(time_interval)
expr_pod_getobject_function = 'sum(kube_pod_container_status_ready{namespace="openfaas-fn",pod=~"getobject.*"})&time='+str(time_interval)
print(pre_url+expr_pod_aeneas_function)
metrics['pod_count_aeneas']=getdataprometheus(pre_url+expr_pod_aeneas_function)
metrics['pod_count_tocloud']=getdataprometheus(pre_url+expr_pod_tocloud_function)
metrics['pod_count_getobject']=getdataprometheus(pre_url+expr_pod_getobject_function)

metrics
# Out:
# http://172.17.141.197:31022//api/v1/query?query=sum(kube_pod_container_status_ready{namespace="openfaas-fn",pod=~"aeneas.*"})&time=1673723269.0
# {'workload_type': '41_30_keda_rps_message_0.5',
#  'workload_size': 41,
#  'Workload TPT': 141.324451,
#  'Average Workload TPT': 22.70693990243902,
#  'Average FET': 22.554160975609754,
#  'CPU_used': '2.9982072728271274',
#  'CPU_requested': '8.5',
#  'CPU_rabbitmq_broker_used': '0.014151552985464347',
#  'Memory_rabbitmq_broker_used': '307495.5795036711',
#  'CPU_rabbitmq_broker_requested': '0.4',
#  'pod_count_rabbitmq': '2',
#  'pod_count_aeneas': '7',
#  'pod_count_tocloud': '1',
#  'pod_count_getobject': '1'}

# %%
df_metrics = pd.read_csv("k8shpa_k8shpa.csv")
df_metrics = df_metrics.append(metrics, ignore_index=True)
# Out:
# /tmp/ipykernel_12809/2758968194.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics = df_metrics.append(metrics, ignore_index=True)

# %%
df_metrics.to_csv("k8shpa_k8shpa.csv",index=False)
display(df_metrics)
# Out:
#    Average Workload TPT  Workload TPT  workload_size  \
# 0              7.797256    105.956321             40
# 1             12.986506    124.608008             40
# 2              9.415233    122.563872             41
# 3              9.415233    122.563872             41
# 4             28.885406    156.924433             45
# 5             10.252060    104.875116             51
# 6             14.183050    105.894944             45
# 7             22.706940    141.324451             41
#
#                 workload_type  Average FET pod_count_aeneas  \
# 0              40_100_k8s_k8s     7.786122                4
# 1              40_100_k8s_k8s    13.099460                4
# 2              41_30_keda_rps    32.728098                7
# 3              41_30_keda_rps    32.728098                1
# 4  45_30_keda_rps_message_0.5    29.077424                1
# 5  51_30_keda_rps_message_0.5     9.894755                4
# 6  45_30_keda_rps_message_0.5    13.895049                4
# 7  41_30_keda_rps_message_0.5    22.554161                7
#
#   pod_count_getobject pod_count_tocloud  pod_count_connector  \
# 0                   1                 1                  NaN
# 1                   1                 1                  NaN
# 2                   1                 1                  NaN
# 3                   1                 1                  NaN
# 4                   1                 1                  NaN
# 5                   1                 1                  NaN
# 6                   1                 1                  NaN
# 7                   1                 1                  NaN
#
#    CPU_rabbitmq_broker CPU_rabbitmq_broker_requested CPU_rabbitmq_broker_used  \
# 0                  NaN                           0.2                 0.021599
# 1                  NaN                           0.2                 0.021599
# 2                  NaN                           0.2                 0.014545
# 3                  NaN                           0.2                 0.007121
# 4                  NaN                           0.4                 0.010965
# 5                  NaN                           0.4                 0.013943
# 6                  NaN                           0.4                 0.017511
# 7                  NaN                           0.4     0.014151552985464347
#
#   CPU_requested            CPU_used  Memory_rabbitmq_broker  \
# 0          11.5            2.576263                     NaN
# 1          13.5            4.072007                     NaN
# 2           2.5            1.825402                     NaN
# 3           2.5            2.340418                     NaN
# 4           1.5            3.051482                     NaN
# 5           8.5            3.974891                     NaN
# 6           5.5            2.971724                     NaN
# 7           8.5  2.9982072728271274                     NaN
#
#   Memory_rabbitmq_broker_used pod_count_rabbitmq
# 0                211346.01804                  1
# 1                491890.24092                  1
# 2               322166.612484                  1
# 3               149044.123647                  1
# 4                279308.84146                  2
# 5               461622.468621                  2
# 6               481544.976658                  2
# 7           307495.5795036711                  2

# %%
# Frequency
stats_df = df \
.groupby('PT') \
['PT'] \
.agg('count') \
.pipe(pd.DataFrame) \
.rename(columns = {'PT': 'frequency'})

# PDF
stats_df['pdf'] = stats_df['frequency'] / sum(stats_df['frequency'])
stats_df['cdf'] = stats_df['pdf'].cumsum()
stats_df = stats_df.reset_index()
display(stats_df)
stats_df.to_csv("stats_df_keda+0.5_rps.csv")
from matplotlib import pyplot as plt

plt.plot(stats_df['PT'],stats_df['cdf'],  linestyle='--', marker='o', color='b', label='k8s_k8s')
#plt.plot(df['user'],df['CT'],  linestyle='--', marker='*', color='r', label='Communication Time')
plt.grid()
plt.legend(loc='best')
plt.xlabel('PT (Seconds)', fontsize=18)
plt.ylabel('CDF', fontsize=16)
# Out:
#       PT  frequency       pdf       cdf
# 0    6.0          3  0.066667  0.066667
# 1    7.0          2  0.044444  0.111111
# 2    8.0          1  0.022222  0.133333
# 3    9.0          1  0.022222  0.155556
# 4   10.0          3  0.066667  0.222222
# 5   11.0          4  0.088889  0.311111
# 6   12.0          6  0.133333  0.444444
# 7   13.0          2  0.044444  0.488889
# 8   14.0          2  0.044444  0.533333
# 9   16.0          2  0.044444  0.577778
# 10  17.0          5  0.111111  0.688889
# 11  18.0          7  0.155556  0.844444
# 12  19.0          1  0.022222  0.866667
# 13  21.0          4  0.088889  0.955556
# 14  22.0          1  0.022222  0.977778
# 15  24.0          1  0.022222  1.000000
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# Text(0, 0.5, 'CDF')
